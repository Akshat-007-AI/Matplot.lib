# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("matplotlib.csv.csv")
df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        799 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
x = df["Speed"]
y = df["Generation"]
plt.plot(x,y)
plt.show()

# %%
plt.plot(df["Generation"],df["Speed"].sort_values(),
color="orange",
linestyle="--",
linewidth=2,
marker="x",
markersize=8,
label="Generation",
alpha=0.8)
plt.title("Generation vs Speed")
plt.xlabel("Generation")
plt.ylabel("Speed")

plt.show()

# %%
plt.scatter(df["Speed"],df["Attack"],
c="green",
s=100,
marker="o",
alpha=0.7,
edgecolors="blue",)
plt.xlabel("Speed")
plt.ylabel("Attack")
plt.title("Speed vs Attack")

plt.show()

# %%
plt.bar(df["Type 1"],df["Speed"],
color="blue",
edgecolor="red",
alpha=0.8)

plt.show()

# %%
plt.barh(df["Type 1"],df["Speed"],
color="blue",
edgecolor="red",
alpha=0.8)

plt.show()

# %%
plt.hist(df["Generation"],
bins=30,
color="ORANGE",
edgecolor="BLUE",
density=True,
)

plt.show()

# %%
plt.boxplot(df["Speed"],
showmeans=True,
patch_artist=True,
)

plt.show()

# %%
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90)

plt.show()

# %%
plt.subplot(121),
plt.bar(df["Type 1"],df["Speed"],
        color="red",
        edgecolor="blue",
        alpha=0.8)
plt.xlabel("Type 1")
plt.ylabel("Speed")
plt.xticks(rotation=90)
plt.title("Speed by Type 1")
plt.tight_layout()

plt.subplot(122),
plt.bar(df["Type 1"],df["Speed"],
        color="red",
        edgecolor="blue",
        alpha=0.8)
plt.xlabel("Type 1")
plt.ylabel("Speed")
plt.xticks(rotation=90)
plt.title("Speed by Type 1")
plt.tight_layout()
plt.show()

# %%
plt.subplot(121),
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90
)
plt.subplot(122),
plt.bar(df["Type 1"],df["Speed"],
        color="red",
        edgecolor="blue",
        alpha=0.8)
plt.xlabel("Type 1")
plt.ylabel("Speed")
plt.xticks(rotation=90)
plt.title("Speed by Type 1")
plt.tight_layout()
plt.show()

# %%
plt.subplot(121),
plt.boxplot(df["Speed"],
showmeans=True,
patch_artist=True,
)

plt.subplot(122),
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90
)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(141)
plt.hist(df["Generation"],
bins=30,
color="ORANGE",
edgecolor="BLUE",
density=True,
)
plt.subplot(142)
plt.scatter(df["Speed"],df["Attack"],
c="green",
s=100,
marker="o",
alpha=0.7,
edgecolors="blue",)
plt.xlabel("Speed")
plt.ylabel("Attack")
plt.title("Speed vs Attack")

plt.subplot(143),
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90
)
plt.subplot(144),
plt.boxplot(df["Speed"],
showmeans=True,
patch_artist=True,
)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(221)
plt.hist(df["Generation"],
bins=30,
color="ORANGE",
edgecolor="BLUE",
density=True,
)
plt.subplot(222)
plt.scatter(df["Speed"],df["Attack"],
c="green",
s=100,
marker="o",
alpha=0.7,
edgecolors="blue",)
plt.xlabel("Speed")
plt.ylabel("Attack")
plt.title("Speed vs Attack")

plt.subplot(223),
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90
)
plt.subplot(224),
plt.boxplot(df["Speed"],
showmeans=True,
patch_artist=True,
)
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.subplot(331)
plt.plot(df["Generation"],df["Speed"].sort_values(),
color="orange",
linestyle="--",
linewidth=2,
marker="x",
markersize=8,
label="Generation",
alpha=0.8)
plt.title("Generation vs Speed")
plt.xlabel("Generation")
plt.ylabel("Speed")
plt.subplot(332)
plt.hist(df["Generation"],
bins=30,
color="ORANGE",
edgecolor="BLUE",
density=True,
)
plt.subplot(333)
plt.scatter(df["Speed"],df["Attack"],
c="green",
s=100,
marker="o",
alpha=0.7,
edgecolors="blue",)
plt.xlabel("Speed")
plt.ylabel("Attack")
plt.title("Speed vs Attack")

plt.subplot(334),
plt.pie(df["Type 1"].value_counts(),
labels=df["Type 1"].value_counts().index,
autopct="%1.1f%%",
startangle=90
)
plt.subplot(335),
plt.boxplot(df["Speed"],
showmeans=True,
patch_artist=True,
)
plt.subplot(336)
plt.barh(df["Type 1"],df["Speed"],
color="blue",
edgecolor="red",
alpha=0.8)

plt.show()

# %%
m = [1,2,3,4,5]
n = [10,20,15,25,30]

plt.stem(m,n)
plt.title("Stem Plot")
plt.xlabel("m values")
plt.ylabel("n values")
# Out:
# Text(0, 0.5, 'n values')

# %%
g = [1,2,3,4,5]
h = [10,20,30,40,50]
plt.step(g,h)
plt.title("Step Plot")

plt.show()

# %%
c = [1,2,3,4,5]
d = [10,15,25,20,30]
plt.fill_between(c,d)
plt.title("Area Plot")
plt.show()

# %%
a = df["Speed"].sort_values()
b = df["Generation"].sort_values()


plt.stem(a,b)
plt.title("Stem Plot")
plt.xlabel("a values")
plt.ylabel("b values")
plt.show()

# %%
e = df["Speed"].sort_values()
f = df["Type 1"].sort_values()
plt.step(e,f)
plt.title("Step Plot")

plt.show()

# %%
c = df["Speed"].sort_values()
d = df["Attack"].sort_values()
plt.fill_between(c,d)
plt.title("Area Plot")
plt.show()
